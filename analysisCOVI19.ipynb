# %%
import pandas as pd
import json

# %%
with open('raw_data.json') as raw_file:
    dict_raw = json.load(raw_file)

# %%
dict_raw.keys()
rd = dict_raw['raw_data']
df_raw = pd.DataFrame(rd)
df_raw.head(15)
# Out:
#    agebracket                                 backupnotes  \
# 0          20                          Student from Wuhan
# 1                                      Student from Wuhan
# 2                                      Student from Wuhan
# 3          45         Travel history to Italy and Austria
# 4          24  Travel history to Dubai, Singapore contact
# 5          69                             Italian tourist
# 6          55                             Italian tourist
# 7          55                             Italian tourist
# 8          55                             Italian tourist
# 9          55                             Italian tourist
# 10         55                             Italian tourist
# 11         55                             Italian tourist
# 12         55                             Italian tourist
# 13         55                             Italian tourist
# 14         55                             Italian tourist
#
# ...
